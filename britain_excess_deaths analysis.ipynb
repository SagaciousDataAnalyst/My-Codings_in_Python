# %%
import pandas as pd

# %%
df=pd.read_csv("britain_excess_deaths.csv")

# %%
df
# Out:
#      country             region region_code  start_date    end_date  year  \
# 0    Britain  England and Wales   K04000001  2020-01-04  2020-01-10  2020
# 1    Britain  England and Wales   K04000001  2020-01-11  2020-01-17  2020
# 2    Britain  England and Wales   K04000001  2020-01-18  2020-01-24  2020
# 3    Britain  England and Wales   K04000001  2020-01-25  2020-01-31  2020
# 4    Britain  England and Wales   K04000001  2020-02-01  2020-02-07  2020
# ..       ...                ...         ...         ...         ...   ...
# 317  Britain            Britain   K02000001  2020-05-09  2020-05-15  2020
# 318  Britain            Britain   K02000001  2020-05-16  2020-05-22  2020
# 319  Britain            Britain   K02000001  2020-05-23  2020-05-29  2020
# 320  Britain            Britain   K02000001  2020-05-30  2020-06-05  2020
# 321  Britain            Britain   K02000001  2020-06-06  2020-06-12  2020
#
#      week  population  total_deaths  covid_deaths  expected_deaths  \
# ...

# %%
df.columns
# Out:
# Index(['country', 'region', 'region_code', 'start_date', 'end_date', 'year',
#        'week', 'population', 'total_deaths', 'covid_deaths', 'expected_deaths',
#        'excess_deaths', 'non_covid_deaths'],
#       dtype='object')

# %%
df["region"].value_counts()
# Out:
# England and Wales           23
# North East                  23
# North West                  23
# Yorkshire and The Humber    23
# East Midlands               23
# West Midlands               23
# East                        23
# London                      23
# South East                  23
# South West                  23
# Wales                       23
# Scotland                    23
# Northern Ireland            23
# Britain                     23
# Name: region, dtype: int64

# %%
df.head(3)
# Out:
#    country             region region_code  start_date    end_date  year  week  \
# 0  Britain  England and Wales   K04000001  2020-01-04  2020-01-10  2020     1
# 1  Britain  England and Wales   K04000001  2020-01-11  2020-01-17  2020     2
# 2  Britain  England and Wales   K04000001  2020-01-18  2020-01-24  2020     3
#
#    population  total_deaths  covid_deaths  expected_deaths  excess_deaths  \
# 0    59115809         14058             0          14131.2          -73.2
# 1    59115809         12990             0          13218.6         -228.6
# 2    59115809         11856             0          12791.8         -935.8
#
#    non_covid_deaths
# 0             14058
# 1             12990
# 2             11856

# %%
df["population"].mean()
# Out:
# 13713350.642857144

# %%
df["start_date"]=pd.to_datetime(df["start_date"])

# %%
df.dtypes
# Out:
# country                     object
# region                      object
# region_code                 object
# start_date          datetime64[ns]
# end_date                    object
# year                         int64
# week                         int64
# population                   int64
# total_deaths                 int64
# covid_deaths                 int64
# expected_deaths            float64
# excess_deaths              float64
# non_covid_deaths             int64
# dtype: object
